# %%
import pandas as pd
import glob
import numpy as np

# %%
folder_path = 'train'
file_list = glob.glob(folder_path + "/*.txt")
main_dataframe = pd.DataFrame(pd.read_table(file_list[0]))
df = pd.DataFrame()
    
for i in range(0,len(file_list)):
    with open(file_list[i]) as f:
        lines = f.readlines()
        lines0 = [line.split()[0] for line in lines]
        lines1 = [line.split()[1:][-1] for line in lines]
        df1 = pd.DataFrame ([lines1[0:-1]], columns = lines0[0:-1])
        df = pd.concat([df, df1], ignore_index=True)
        
  
# creating a new csv file with
# the dataframe we created
df.to_csv('new_csv3.csv')

# %%
df.shape
# Out:
# (4, 20)

# %%
folder_path = 'train'
file_list = glob.glob(folder_path + "/*.txt")

with open(file_list[0]) as f:
    lines = f.readlines()
    lines0 = [line.split()[0] for line in lines]
    lines1 = [line.split()[1:][-1] for line in lines]
    new_dic_lis = dict(zip(lines0, lines1))
    print(new_dic_lis)
    print(lines1[0:-1])
# Out:
# {'ID': '0x4607', 'Delivery_person_ID': 'INDORES13DEL02', 'Delivery_person_Age': '37.000000', 'Delivery_person_Ratings': '4.900000', 'Restaurant_latitude': '22.745049', 'Restaurant_longitude': '75.892471', 'Delivery_location_latitude': '22.765049', 'Delivery_location_longitude': '75.912471', 'Order_Date': '19-03-2022', 'Time_Orderd': '11:30', 'Time_Order_picked': '11:45', 'Weather': 'Sunny', 'Road_traffic_density': 'High', 'Vehicle_condition': '2', 'Type_of_order': 'Snack', 'Type_of_vehicle': 'motorcycle', 'multiple_deliveries': '0.000000', 'Festival': 'No', 'City': 'Urban', 'Time_taken': '24.000000', 'Name:': 'object'}
# ['0x4607', 'INDORES13DEL02', '37.000000', '4.900000', '22.745049', '75.892471', '22.765049', '75.912471', '19-03-2022', '11:30', '11:45', 'Sunny', 'High', '2', 'Snack', 'motorcycle', '0.000000', 'No', 'Urban', '24.000000']

# %%
df5 = pd.read_csv('new_csv3.csv')

# %%
df5 = df5.drop(columns='Unnamed: 0')

# %%
df5.shape
# Out:
# (45593, 20)

# %%
df4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 df4
#
# NameError: name 'df4' is not defined

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  object
#  2   Delivery_person_Age          45593 non-null  int32
#  3   Delivery_person_Ratings      45593 non-null  float64
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Order_Date                   45593 non-null  object
#  9   Time_Orderd                  45593 non-null  object
#  10  Time_Order_picked            45593 non-null  datetime64[ns]
#  11  Weather                      44977 non-null  object
# ...

# %%
df5[df5['Delivery_person_Age'].isna()].shape
# Out:
# (1854, 20)

# %%
df5[df5['new_column1'].isna()]
# Out:
# Empty DataFrame
# Columns: [ID, Delivery_person_ID, Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Order_Date, Time_Orderd, Time_Order_picked, Weather, Road_traffic_density, Vehicle_condition, Type_of_order, Type_of_vehicle, multiple_deliveries, Festival, City, Time_taken, new_column1]
# Index: []
#
# [0 rows x 21 columns]

# %%
df5['new_column1']=np.vectorize(transform_time)(df5['Time_Order_picked'],df5['Time_Orderd'])
# Out:
# 11:45 11:30
# 11:45 11:30
# 19:50 19:45
# 8:45 8:30
# 18:10 17:60
# 13:45 13:30
# 21:30 21:20
# 19:30 19:15
# 17:30 17:25
# 21:05 20:55
# 22:10 21:55
# 15:05 14:55
# 17:40 17:30
# 9:30 9:20
# 20:05 19:50
# 20:35 20:25
# 15:10 14:55
# 20:40 20:30
# 20:50 20:40
# 21:30 21:15
# 20:25 20:20
# 22:45 22:30
# 8:30 8:15
# 19:45 19:30
# 12:30 12:25
# 18:50 18:35
# 20:40 20:35
# 23:30 23:20
# 21:35 21:20
# 23:45 23:35
# 22:50 22:35
# 22:40 22:35
# 23:35 23:25
# 13:40 13:35
# 21:45 21:35
# 22:45 22:35
# 19:10 18:55
# 14:25 14:15
# 11:10 10:60
# 9:55 9:45
# 8:55 8:40
# 23:10 22:60
# 17:30 17:25
# 18:35 nan
# 19:50 19:45
# 19:25 19:10
# 10:60 10:55
# 21:45 21:40
# 19:15 18:60
# 16:55 16:45
# 11:40 11:30
# 15:15 15:10
# 22:55 22:45
# 22:25 22:10
# 20:55 20:45
# 23:05 22:50
# 17:60 17:55
# 22:60 22:45
# 20:50 20:35
# 9:40 9:25
# 20:20 20:15
# 22:35 22:25
# 21:60 21:55
# 22:55 22:40
# 23:55 23:50
# 15:40 15:25
# 10:30 10:20
# 20:60 20:55
# 10:50 10:40
# 16:05 15:55
# 20:15 20:10
# 12:15 12:10
# ...

# %%
format(df5['new_column1'].mean(), '.1f')
# Out:
# '10.0'

# %%
pd.to_datetime(df5['new_column'],format="%M")
# Out:
# 0       1900-01-01 00:15:00
# 1       1900-01-01 00:05:00
# 2       1900-01-01 00:15:00
# 3       1900-01-01 00:10:00
# 4       1900-01-01 00:15:00
#                 ...
# 45588   1900-01-01 00:10:00
# 45589   1900-01-01 00:15:00
# 45590   1900-01-01 00:15:00
# 45591   1900-01-01 00:05:00
# 45592   1900-01-01 00:05:00
# Name: new_column, Length: 45593, dtype: datetime64[ns]

# %%
pd.to_datetime(15,format="%M")
# Out:
# Timestamp('1900-01-01 00:15:00')

# %%
df5['new_column1'] = df5['new_column1'].fillna(format(df5['new_column1'].mean(), '.1f'))

# %%
df5['new_column1'] = df5['new_column1'].astype(float)

# %%
df5['Time_Order_picked']=df5['Time_Order_picked'].apply(transform_time_order_picked)
# Out:
# 11:45
# 19:50
# 8:45
# 18:10
# 13:45
# 21:30
# 19:30
# 17:30
# 21:05
# 22:10
# 15:05
# 17:40
# 9:30
# 20:05
# 20:35
# 15:10
# 20:40
# 20:50
# 21:30
# 20:25
# 22:45
# 8:30
# 19:45
# 12:30
# 18:50
# 20:40
# 23:30
# 21:35
# 23:45
# 22:50
# 22:40
# 23:35
# 13:40
# 21:45
# 22:45
# 19:10
# 14:25
# 11:10
# 9:55
# 8:55
# 23:10
# 17:30
# 18:35
# 19:50
# 19:25
# 10:60
# 21:45
# 19:15
# 16:55
# 11:40
# 15:15
# 22:55
# 22:25
# 20:55
# 23:05
# 17:60
# 22:60
# 20:50
# 9:40
# 20:20
# 22:35
# 21:60
# 22:55
# 23:55
# 15:40
# 10:30
# 20:60
# 10:50
# 16:05
# 20:15
# 12:15
# 15:45
# 22:15
# 10:45
# 15:30
# 24:05
# 21:25
# 20:40
# 20:60
# 12:45
# 21:15
# 23:55
# 18:20
# 18:25
# 11:50
# 20:55
# 22:10
# 12:50
# 23:45
# 10:55
# 21:40
# 10:20
# 23:05
# 8:55
# 17:55
# 20:40
# 22:25
# 23:50
# 23:30
# 12:55
# 23:45
# 24:10
# 22:60
# 10:40
# 8:60
# 21:40
# 22:40
# 20:20
# 11:10
# 20:45
# 23:35
# 10:50
# 23:50
# 19:60
# 22:25
# 23:15
# 9:30
# 18:35
# 22:20
# 21:05
# 18:25
# 18:50
# 15:05
# 16:60
# 22:35
# 24:15
# ...

# %%
df5['Time_Order_picked']=pd.to_datetime(df5['Time_Order_picked'].replace("24:00","23:59", regex=True))+ pd.Timedelta(1, 'min')

# %%
df5['Time_Orderd']=pd.to_datetime(df5['Time_Orderd'].replace(":60",":59", regex=True)) + pd.Timedelta(1, 'min')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\dateutil\parser\_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\dateutil\parser\_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: day is out of range for month
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# ...

# %%
df5[df5['Time_Orderd'].isna()].shape
# Out:
# (1731, 21)

# %%
format(df5['new_column1'].mean(), '.0f')
# Out:
# '10'

# %%
df5['Time_Orderd'] = df5['Time_Orderd'].fillna(df5['Time_Order_picked']- pd.to_datetime(format(df5['new_column1'].mean(), '.0f'),format="%M"))

# %%
df5['Time_Orderd'].unique()
# Out:
# array(['11:30', '19:45', '8:30', '0.75', '13:30', '21:20', '19:15',
#        '17:25', '20:55', '21:55', '14:55', '17:30', '9:20', '19:50',
#        '20:25', '20:30', '20:40', '21:15', '20:20', '22:30', '8:15',
#        '19:30', '12:25', '18:35', '20:35', '23:20', '23:35', '22:35',
#        '23:25', '13:35', '21:35', '18:55', '14:15', '0.458333333', '9:45',
#        '8:40', '0.958333333', nan, '19:10', '10:55', '21:40',
#        '0.791666667', '16:45', '15:10', '22:45', '22:10', '20:45',
#        '22:50', '17:55', '9:25', '20:15', '22:25', '22:40', '23:50',
#        '15:25', '10:20', '10:40', '15:55', '20:10', '12:10', '15:30',
#        '10:35', '21:10', '20:50', '12:35', '0.875', '23:40', '18:15',
#        '18:20', '11:45', '12:45', '23:30', '10:50', '21:25', '10:10',
#        '17:50', '22:20', '12:40', '23:55', '10:25', '8:45', '23:45',
#        '19:55', '22:15', '23:10', '9:15', '18:25', '18:45', '16:50', '1',
#        '14:20', '10:15', '8:50', '0.375', '17:45', '16:35', '21:45',
# ...

# %%
df5[df5['Time_Order_picked']=="20:40"]
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 16     0x689b     PUNERES20DEL01                   33
# 25     0x3231      JAPRES16DEL03                   27
# 77     0xb962     CHENRES11DEL03                   35
# 95     0xb437      SURRES16DEL01                   25
# 187    0x2fe1      SURRES18DEL03                   27
# ...       ...                ...                  ...
# 45046  0xd99b     AURGRES05DEL03                   34
# 45109  0x3b6e     BANGRES02DEL01                   37
# 45231  0x5df8      HYDRES08DEL02                   35
# 45451  0x1534     CHENRES05DEL03                   37
# 45581  0x51f0      SURRES02DEL03                   20
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 16                         4.2            18.592718             73.773572
# 25                         5.0            26.849596             75.800512
# 77                         4.1            13.064181             80.236442
# ...

# %%
def transform_time(t1,t2):
    t1= str(t1)
    t2= str(t2)
    print(t1,t2)
    if(":" not in t1 or ":" not in t2):
        return float('NaN')
    else:
        t1h = int(t1.split(":")[0])*60
        t1m = int(t1.split(":")[1][0:2])
        t2h = int(t2.split(":")[0])*60
        t2m = int(t2.split(":")[1][0:2])
        total_time1 = t1h+t1m
        total_time2 = t2h+t2m
        return float(total_time1 - total_time2)

# %%
def transform_time_order_picked(t):
    t= str(t)
    print(t)
    if(":" not in t):
        return float('NaN')
    else:
        if(int(t.split(":")[1])>=60):
            t=t.replace(str(t.split(":")[1]),"00")
            t=t.replace(t.split(":")[0],str(int(t.split(":")[0])+1))
        elif(int(t.split(":")[0])>=24):
            t=t.replace(str(t.split(":")[0]),"0")
            
        return t

# %%
transform_time_order_picked('20:40')
# Out:
# 20:40
# '20:40'

# %%
time_1 = datetime.datetime.strptime(df3['Time_Orderd'],"%H:%M")
time_2 = datetime.datetime.strptime(df3['Time_Order_picked'],"%H:%M")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [265], in <cell line: 1>()
# ----> 1 time_1 = datetime.datetime.strptime(df3['Time_Orderd'],"%H:%M")
#       2 time_2 = datetime.datetime.strptime(df3['Time_Order_picked'],"%H:%M")
#
# TypeError: strptime() argument 1 must be str, not Series

# %%
transform_time('16:00','15:00')
# Out:
# 60

# %%
import datetime

# %%
time_1.total_seconds()+time_2.total_seconds()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [263], in <cell line: 1>()
# ----> 1 time_1.total_seconds()+time_2.total_seconds()
#
# AttributeError: 'datetime.datetime' object has no attribute 'total_seconds'

# %%
pd.to_datetime(df3['Time_Orderd'], format=’%y%m%d’)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\tools\datetimes.py:510, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     509 try:
# --> 510     values, tz = conversion.datetime_to_datetime64(arg)
#     511     dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [258], in <cell line: 1>()
# ----> 1 pd.to_datetime(df3['Time_Orderd'], format="%H:%M")
#
# ...

# %%
time_interval = time_2 - time_1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [264], in <cell line: 1>()
# ----> 1 time_interval = time_2.total_seconds()
#
# AttributeError: 'datetime.datetime' object has no attribute 'total_seconds'

# %%
time_interval.total_seconds()/60
# Out:
# 15.0

# %%
df5['Delivery_person_Age'].mean()
# Out:
# 29.567136880129862

# %%
df5['Delivery_person_Age'].mean()
# Out:
# 29.567136880129862

# %%
df5['Delivery_person_Age'] = df5['Delivery_person_Age'].fillna(df5['Delivery_person_Age'].mean())

# %%
df5['Delivery_person_Age'] = df5['Delivery_person_Age'].astype(int)

# %%
format(df5['Delivery_person_Ratings'].mean(), '.1f')
# Out:
# '4.6'

# %%
df5['Delivery_person_Ratings'] = df5['Delivery_person_Ratings'].fillna(format(df5['Delivery_person_Ratings'].mean(), '.1f'))

# %%
df5['Delivery_person_Ratings'] = df5['Delivery_person_Ratings'].astype(float)

# %%
from math import radians, sin, cos, acos

print("Input coordinates of two points:")
slat = radians(float(input("Starting latitude: ")))
slon = radians(float(input("Ending longitude: ")))
elat = radians(float(input("Starting latitude: ")))
elon = radians(float(input("Ending longitude: ")))

dist = 6371.01 * acos(sin(slat)*sin(elat) + cos(slat)*cos(elat)*cos(slon - elon))
print("The distance is %.2fkm." % dist)
# Out:
# Input coordinates of two points:
# Starting latitude: 22.745049
# Ending longitude: 75.892471
# Starting latitude: 22.765049
# Ending longitude: 75.912471
# The distance is 3.03km.
